# %%
# IMPORTS
import pydicom
import matplotlib.pyplot as plt
import numpy as np
import copy

# %%
def Transformation(image, transform):
    # This function is transforming an image with the Transform vector
    newArr = copy.deepcopy(image)
    for i in range(len(image)):
        for j in range(len(image[i])):
            newArr[i, j] = transform[image[i, j]]
    return newArr

# %%
# Show one image
ds = pydicom.read_file("data/IM-0001-0001-0001.dcm")
arr = ds.pixel_array
plt.imshow(arr, cmap='Greys') #cmap='Greys'
plt.title('Image non traitée')
# Out:
# Text(0.5, 1.0, 'Image non traitée')

# %%
# Plot histogram of the image above
def histogram(arr):
    maxValue = np.max(arr)
    h,w = arr.shape
    n = h*w
    histogram = np.array([0]*(maxValue+1))
    for i in arr:
        for j in i:
            histogram[j] += 1
    histogram_n = histogram/n#histogramme normalisé --> plus visible
    return histogram_n
# We see the histogram does not need any stretching, but needs to be crimped

# %%
# Transformation or crimping procedure
def crimping(arr):
    maxValue = np.max(arr)
    histo = histogram(arr)
    Transform = np.arange(0,  maxValue + 1) # This will be the transformation vector
    deltaA = (maxValue - np.min(np.where(histo > 0)))/(255)
    Transform = np.ceil(Transform / deltaA)   
    # Apply the transformation to the original image
    newArr = Transformation(arr, Transform)
    return newArr
    # Plot final figure
    plt.imshow(newArr, cmap='Greys')
    # Plot des histogrammes
    plt.figure()
    plt.subplot(1,2,1)
    plt.plot()

# %%
#plot des figures et histogrammes 
newArr = crimping(arr)
histo = histogram(arr)#histogramme de l image non traitee
histogram_lin = histogram(newArr)#histograme de l image apres crimping

#plot des figures
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
plt.imshow(arr, cmap='Greys')
plt.title('Image non traitée')
plt.subplot(1,2,2)
plt.imshow(newArr,cmap='Greys')
plt.title('Image après crimping')

#plot des histogrammes
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
plt.plot(histo)
plt.title('Histogramme de l image non traitée')
plt.subplot(1,2,2)
plt.plot(histogram_lin)
plt.title('Histogramme de l image apres crimping')
# Out:
# Text(0.5, 1.0, 'Histogramme de l image apres crimping')

# %%
#Egalisation des histogrammes
def equalize(arr):
    h,w = arr.shape
    n = h*w
    C = ((344-1)/n)
    new_arr = np.zeros((h,w),dtype=int)
    histo = histogram(arr)*n
    for i in range(h):
        for j in range(w):
            value = arr[i,j]
            new_arr[i,j] = C*(np.sum(histo[0:value+1]))
    return new_arr

# %%
#plot des figures et histogrammes 
arr_equal = equalize(arr)
histo = histogram(arr)#histogramme de l image non traitee
histogram_egal = histogram(arr_equal)#histogramme de l image apres crimping

#plot des figures
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
plt.imshow(arr, cmap='Greys')
plt.title('Image non traitée')
plt.subplot(1,2,2)
plt.imshow(newArr,cmap='Greys')
plt.title('Image après égalisation de l histogramme')

#plot des histogrammes
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
plt.plot(histo)
plt.title('Histogramme de l image non traitée')
plt.subplot(1,2,2)
plt.plot(histogram_egal)
plt.title('Histogramme de l image apres égalisation')
# Out:
# 344
# Text(0.5, 1.0, 'Histogramme de l image apres égalisation')

# %%
def cumulative(arr):
    maxValue = np.max(arr)
    cumul = np.zeros((maxValue))
    histo = histogram(arr)
    for i in range(len(cumul)):
        cumul[i] = np.sum(histo[0:i+1])
    return cumul

# %%
plt.figure()
cumul = cumulative(arr_equal)
plt.plot(cumul)
